# %% [markdown]
# <div style="background: linear-gradient(120deg, #1ca9c9 0%, #40c4d6 60%, #7fe0e0 100%); padding: 28px 36px; border-radius: 14px; display: flex; align-items: center; gap: 28px; box-shadow: 0 4px 18px rgba(0,0,0,0.18);">
#     <img src='Figures/iteso.jpg' style="height: 110px; border-radius: 8px; background: white; padding: 6px; flex-shrink: 0; box-shadow: 0 2px 8px rgba(0,0,0,0.2);"/>
#     <div style="border-left: 2px solid rgba(255,255,255,0.4); padding-left: 28px;">
#         <h1 style="margin: 0 0 8px 0; color: white; font-size: 1.5em; line-height: 1.3;">Actividad 1: Repaso Python y Librerías</h1>
#         <h3 style="margin: 0; color: rgba(255,255,255,0.8); font-weight: normal; font-size: 1.05em;">Laboratorio de Procesamiento de Datos</h3>
#     </div>
# </div>

# %% [markdown]
# Pon en práctica lo aprendido. Resuelve cada ejercicio en las celdas de código de abajo.
#
# ### NumPy
#
# **Ejercicio 1:**
#
# 1. Crear un vector con valores del 1 al 120.
# 2. Crear una función recibe_vector que reciba el vector y, dentro de la función, eleve al cuadrado aquellos números divisibles por 3, y regrese esos números en un nuevo vector.
# 3. Redimensionar el vector que devuelve la función anterior en una matriz de 20×2.
# 4. Crear una nueva matriz de 2×10 y multiplicarla por la matriz anterior.
# 5. Obtener la transpuesta de la matriz resultante.

# %%
import numpy as np

vector = np.arange(1, 121)

def recibe_vector(v):
    divisibles = v[v % 3 == 0] 
    return divisibles ** 2 

vector_funcion = recibe_vector(vector)

matriz_red = vector_funcion.reshape(20, 2)
matriz_nueva = np.ones((2, 10)) 
matriz_res = matriz_red @ matriz_nueva 
matriz_trans = matriz_res.T

print("Matriz transpuesta: ", matriz_trans)
# Out:
# Matriz transpuesta:  [[   45.   225.   549.  1017.  1629.  2385.  3285.  4329.  5517.  6849.
#    8325.  9945. 11709. 13617. 15669. 17865. 20205. 22689. 25317. 28089.]
#  [   45.   225.   549.  1017.  1629.  2385.  3285.  4329.  5517.  6849.
#    8325.  9945. 11709. 13617. 15669. 17865. 20205. 22689. 25317. 28089.]
#  [   45.   225.   549.  1017.  1629.  2385.  3285.  4329.  5517.  6849.
#    8325.  9945. 11709. 13617. 15669. 17865. 20205. 22689. 25317. 28089.]
#  [   45.   225.   549.  1017.  1629.  2385.  3285.  4329.  5517.  6849.
#    8325.  9945. 11709. 13617. 15669. 17865. 20205. 22689. 25317. 28089.]
#  [   45.   225.   549.  1017.  1629.  2385.  3285.  4329.  5517.  6849.
#    8325.  9945. 11709. 13617. 15669. 17865. 20205. 22689. 25317. 28089.]
#  [   45.   225.   549.  1017.  1629.  2385.  3285.  4329.  5517.  6849.
#    8325.  9945. 11709. 13617. 15669. 17865. 20205. 22689. 25317. 28089.]
#  [   45.   225.   549.  1017.  1629.  2385.  3285.  4329.  5517.  6849.
#    8325.  9945. 11709. 13617. 15669. 17865. 20205. 22689. 25317. 28089.]
#  [   45.   225.   549.  1017.  1629.  2385.  3285.  4329.  5517.  6849.
#    8325.  9945. 11709. 13617. 15669. 17865. 20205. 22689. 25317. 28089.]
#  [   45.   225.   549.  1017.  1629.  2385.  3285.  4329.  5517.  6849.
#    8325.  9945. 11709. 13617. 15669. 17865. 20205. 22689. 25317. 28089.]
#  [   45.   225.   549.  1017.  1629.  2385.  3285.  4329.  5517.  6849.
#    8325.  9945. 11709. 13617. 15669. 17865. 20205. 22689. 25317. 28089.]]

# %% [markdown]
# **Ejercicio 2:**
#
# Se desea calcular el índice de masa corporal (IMC) de jugadores de un equipo de futbol. Los datos proporcionados corresponden a las listas de los nombres, altura y peso, tal como se muestra a continuación

# %%
nombre= ['Bonifacio de Cifuentes',
'Ángel Machado Lara',
'Geraldo de Atienza',
'Onofre Posada Grande',
'Samu Cantón-Figuerola',
'Camilo Pol',
'Toni Galvez Lara',
'Lucho Manzano Rivas',
'Abraham Aroca',
'Anselmo Bartolomé Folch',
'Toni Inocencio Rozas Porras',
'Fausto Cortés-Arco',
'Baltasar Carreño Isern']

altura = [180, 215, 210, 210, 188, 176, 209, 200, 210, 188, 176, 209, 200]
peso = [69, 74, 72, 75, 68, 70, 71, 73, 69, 74, 72, 75, 68]

# %% [markdown]
# El valor de IMC por cada jugador resulta de aplicar la fórmula:
#
# $$IMC = \frac{peso(kg)}{altura(m)^2}$$
#
# **Nota:** Los valores de altura están dados en centímetros por lo que deberá hacer laconversión a metros previo a la aplicación de la fórmula. Adicionalmente, una vez obtenido el IMC se solicita:
#
# > a) Presentar el icm para cada jugador.
#
# > b) Indicar en qué índice se encuentra el icm más alto y a qué jugador le pertenece.
#
# > c) Calcular el promedio de los icm resultantes.
#
# > d) Muestre los nombres de los jugadores en orden de su imc, desde el que tiene menorimc al que tiene mayor imc.

# %%
altura = np.array(altura)
peso = np.array(peso)
nombre = np.array(nombre)

alturas_m = altura / 100
imc = peso / (alturas_m ** 2)

print("IMC por jugador:")
for jugador, valor in zip(nombre, imc):
    print(jugador, valor)

indice_alto = np.argmax(imc)
jugador_alto = nombre[indice_alto]
print("El IMC más alto está en el índice", indice_alto, "perteneciente a", jugador_alto)

promedio_imc = np.mean(imc)
print("El promedio de los IMC es:", promedio_imc)

indices_ordenados = np.argsort(imc)
nombres_ordenados = np.array(nombre)[indices_ordenados]

print("Jugadores ordenados por IMC (de menor a mayor):")
for nombre in nombres_ordenados:
    print(nombre)
# Out:
# IMC por jugador:
# Bonifacio de Cifuentes 21.296296296296294
# Ángel Machado Lara 16.00865332612223
# Geraldo de Atienza 16.3265306122449
# Onofre Posada Grande 17.006802721088434
# Samu Cantón-Figuerola 19.23947487550928
# Camilo Pol 22.59814049586777
# Toni Galvez Lara 16.2542066344635
# Lucho Manzano Rivas 18.25
# Abraham Aroca 15.64625850340136
# Anselmo Bartolomé Folch 20.937075599818925
# Toni Inocencio Rozas Porras 23.243801652892564
# Fausto Cortés-Arco 17.16993658570088
# Baltasar Carreño Isern 17.0
# El IMC más alto está en el índice 10 perteneciente a Toni Inocencio Rozas Porras
# El promedio de los IMC es: 18.536705946415857
# Jugadores ordenados por IMC (de menor a mayor):
# Abraham Aroca
# Ángel Machado Lara
# Toni Galvez Lara
# Geraldo de Atienza
# Baltasar Carreño Isern
# Onofre Posada Grande
# Fausto Cortés-Arco
# Lucho Manzano Rivas
# Samu Cantón-Figuerola
# Anselmo Bartolomé Folch
# Bonifacio de Cifuentes
# Camilo Pol
# Toni Inocencio Rozas Porras

# %% [markdown]
# ### Pandas
#
# **Ejercicio 3:**
#
# Usando el archivo `housing_prices.csv`:
#
# 1. Carga el archivo en un `DataFrame` con `pd.read_csv`.
# 2. Muestra las primeras 5 filas y las estadísticas descriptivas.
# 3. Crea una columna `precio_por_pie` = `price` / `size`.
# 4. Filtra y muestra solo las casas con más de 3 recámaras.
# 5. Calcula el precio promedio agrupando por número de recámaras (`groupby`).
# 6. Grafica un histograma de la columna `price` con `df['price'].plot(kind='hist')`.

# %%
import pandas as pd

casas = pd.read_csv('/Users/matmtz/Desktop/GitHub/Laboratorio_de_Procesamiento_de_Datos_02026/Modulo I/Data/housing_prices.csv')
display(casas.head())
display(casas.describe())

casas['precio_por_pie'] = casas['price'] / casas['size']

casas_mas3hab = casas[casas['n_bedrooms'] > 3]
display(casas_mas3hab) 

precio_prom_recamara = casas.groupby('n_bedrooms')['price'].mean()
display(precio_prom_recamara)

casas['price'].plot(kind='hist', title='Precios', color='skyblue', edgecolor='black')
# Out:
#    size  n_bedrooms   price
# 0  2104           3  399900
# 1  1600           3  329900
# 2  2400           3  369000
# 3  1416           2  232000
# 4  3000           4  539900
#               size  n_bedrooms          price
# count    47.000000   47.000000      47.000000
# mean   2000.680851    3.170213  340412.659574
# std     794.702354    0.760982  125039.899586
# min     852.000000    1.000000  169900.000000
# 25%    1432.000000    3.000000  249900.000000
# 50%    1888.000000    3.000000  299900.000000
# 75%    2269.000000    4.000000  384450.000000
# max    4478.000000    5.000000  699900.000000
#     size  n_bedrooms   price  precio_por_pie
# 4   3000           4  539900      179.966667
# 5   1985           4  299900      151.083123
# 10  1940           4  239999      123.710825
# 13  4478           5  699900      156.297454
# 15  2300           4  449900      195.608696
# 18  2609           4  499998      191.643542
# 19  3031           4  599000      197.624546
# 23  1962           4  259900      132.466871
# 32  2040           4  314900      154.362745
# 34  1811           4  285900      157.868581
# 37  2132           4  345000      161.819887
# 38  4215           4  549000      130.249110
# 39  2162           4  287000      132.747456
# 42  2567           4  314000      122.321776
# 45  1852           4  299900      161.933045
# n_bedrooms
# 1    169900.000000
# 2    280866.666667
# 3    326403.920000
# 4    377449.785714
# 5    699900.000000
# Name: price, dtype: float64
# <Axes: title={'center': 'Precios'}, ylabel='Frequency'>
